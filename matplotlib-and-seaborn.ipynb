# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
yield_apples = [0.895,0.91,0.919,0.926,0.929]
years  = [2002,1992,2004,2004,2006]

# %%
sns.set_style("whitegrid")

plt.plot(years,yield_apples)

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
yield_apples = [0.895,0.91,0.919,0.926,0.929]
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
plt.plot(yield_apples)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
yield_oranges = [0.895,0.91,0.919,0.926,0.929]

# %%
plt.figure(figsize =(12,6))
#plt.plot(yield_oranges, 'or')

# %%
#formating of the styling in the graph plotted
#1)Line markers
#you can show markers for each data point on each line using the marer argument

data =[12,14,17,24,12,13,27]
sns.set_style('darkgrid')

plt.plot(data, 's--b')

plt.xlabel('data1')
plt.ylabel('data2')
plt.title('mapping of data')
plt.legend(['data'])

# %%
#if the line part is not defined then only the markers are shown
import matplotlib.pyplot as plt
import seaborn as sns
data =[12,14,17,24,12,13,27]
plt.plot(data,'or')

# %%
plt.figure(figsize=(12,6))
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'
plt.plot(data,'or')

# %%
flowers_df = sns.load_dataset("iris")

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.plot(flowers_df.sepal_length, flowers_df.sepal_width)

# %%
#but the above output s not very informative as there are to many combinations
#so we use the scatter plot
import matplotlib.pyplot as plt
import seaborn as sns
flowers_df = sns.load_dataset("iris")
plt.title("sepal dimensions")
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width)
# Out:
# <AxesSubplot:title={'center':'sepal dimensions'}, xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.hist(flowers_df.sepal_length, bins=2)
#bins refer to the size of the width bixes determining the data
# Out:
# (array([89., 61.]), array([4.3, 6.1, 7.9]), <BarContainer object of 2 artists>)

# %%
import numpy as np
versicolor_df = flowers_df[flowers_df.species=='versicolor']
setosa_df=flowers_df[flowers_df.species =='setosa']

# %%
plt.hist(setosa_df.sepal_width, alpha=0.4, bins=np.arange(2, 5, 0.25));
plt.hist(versicolor_df.sepal_width, alpha=0.4, bins=np.arange(2, 5, 0.25));

# %%
years=range(2000, 2006)
apples=[0.34,2.5,0.23, 0.8, 1, 0.65]
oranges=[0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
plt.bar(years ,oranges, color='r')
plt.bar(years, apples, color='b')
# Out:
# <BarContainer object of 6 artists>

# %%
tips_df=sns.load_dataset('tips')

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#we compute average bill accross different days of the week
#barplot automatically computes the average 
sns.barplot(x='day', y='total_bill',data=tips_df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(y="day", x='total_bill', hue="sex", data=tips_df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
flights_df=sns.load_dataset("flights").pivot("month", "year", "passengers")
flights_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.title("No. of passengers")
sns.heatmap(flights_df)
# Out:
# <AxesSubplot:title={'center':'No. of passengers'}, xlabel='year', ylabel='month'>

# %%
#import the image from internet using the url
from urllib.request import urlretrieve 
urlretrieve('https://i.imgur.com/SkPbq.jpg', 'chart.jpg');

# %%
#before displaying an image we will read it into the memory(using the PIL module)
from PIL import Image
img = Image.open('chart.jpg')

# %%
img_array = np.array(img)

# %%
img_array.shape
# Out:
# (481, 640, 3)

# %%
plt.imshow(img)

# %%
#we can also plot multiple charts in a grid using plt.subplots
import matplotlib.pyplot as plt
import seaborn as sns
flowers_df=sns.load_dataset("iris")
sns.pairplot(flowers_df,hue='species')
